# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhonatan1599/Fault_diagnosis/blob/fault/Inspeccion_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('./data_01.xlsx', index_col=0)
data
# Out:
#                   MAP       MAF  velocidad_motor  posicion_acelerador  \
# tiempo
# 0.000000     0.054752  0.007331       123.216611             7.247208
# 0.050013     0.053873  0.007622       126.347235             7.814976
# 0.100013     0.052701  0.007974       129.435445             7.779490
# 0.150161     0.051822  0.008096       132.390455             7.744005
# 0.200415     0.052408  0.008470       134.832297             8.702114
# ...               ...       ...              ...                  ...
# 1803.244160  0.023309  0.002194        91.468948             2.172777
# 1803.294055  0.023992  0.002203        91.644391             2.137291
# 1803.344241  0.023114  0.002200        91.594958             2.172777
# 1803.394400  0.024383  0.002203        91.629690             2.137291
# 1803.444057  0.023114  0.002197        91.551578             2.208262
#
#              masa_combustible_inyectado
# tiempo
# 0.000000                       0.001153
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 36068 entries, 0.0 to 1803.444057
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   MAP                         36068 non-null  float64
#  1   MAF                         36068 non-null  float64
#  2   velocidad_motor             36068 non-null  float64
#  3   posicion_acelerador         36068 non-null  float64
#  4   masa_combustible_inyectado  36068 non-null  float64
# dtypes: float64(5)
# memory usage: 1.7 MB

# %%
# Filtrar los datos para incluir solo los primeros 60 segundos
data_subset = data[data.index <= 60]

# Crear la figura y los ejes
fig, ax = plt.subplots()

# Graficar solo la variable MAP en el eje Y izquierdo
ax.plot(data_subset.index, data_subset['MAP'], color='blue', label='MAP')
ax.set_xlabel('Tiempo (s)')
ax.set_ylabel('MAP (MPa)')

# Añadir leyenda
ax.legend(loc='upper left')

# Mostrar la gráfica
plt.show()

# %%
# Filtrar los datos para incluir solo los primeros 60 segundos
data_subset = data

# Crear la figura y los ejes
fig, ax = plt.subplots()

# Graficar solo la variable velocidad_motor en el eje Y izquierdo
ax.plot(data_subset.index, data_subset['velocidad_motor'], color='green', label='Velocidad del Motor')
ax.set_xlabel('Tiempo (s)')
ax.set_ylabel('Velocidad del Motor (RPM)')

# Añadir leyenda
ax.legend(loc='upper left')

# Mostrar la gráfica
plt.show()

# %%
# Filtrar los datos para incluir solo los primeros 60 segundos
data_subset = data[data.index <= 60]

# Crear la figura y los ejes
fig, ax = plt.subplots()

# Graficar solo la variable posicion_acelerador en el eje Y derecho
ax.plot(data_subset.index, data_subset['posicion_acelerador'], color='red', label='Posición del Pedal de Aceleración')
ax.set_ylabel('Posición del Pedal de Aceler. (%)')
ax.set_xlabel('Tiempo (s)')

# Añadir leyenda
ax.legend(loc='upper left')

# Mostrar la gráfica
plt.show()

# %%
# Crear la figura y los ejes
fig, ax1 = plt.subplots()

# Graficar MAP en el eje Y izquierdo
ax1.plot(data.index, data['MAP'], color='blue', label='MAP')
ax1.set_xlabel('Tiempo (s)')
ax1.set_ylabel('MAP (MPa)', color='blue')
ax1.tick_params('y', colors='blue')

# Crear un segundo eje Y para posicion_acelerador y masa_combustible_inyectado
ax2 = ax1.twinx()

# Escalar los valores de injected_fuel_mass para ajustar la escala
scaling_factor = 10000  # Ajusta este valor según tu preferencia
ax2.plot(data.index, data['posicion_acelerador'], color='green', label='Posicion del pedal de aceleración')
ax2.plot(data.index, data['masa_combustible_inyectado'] * scaling_factor, color='red', label='Masa de combustible inyectada (escalado)')
ax2.set_ylabel('Posicion del pedal de aceleración (%)\n Masa de combustible inyectado (g)', color='black')
ax2.tick_params('y', colors='black')

# Añadir leyenda
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

# Mostrar la gráfica
plt.show()

# %%
# Filtrar los datos para incluir solo los primeros 120 segundos
data_subset = data[data.index <= 2]

# Crear la figura y los ejes
fig, ax1 = plt.subplots()

# Graficar MAP en el eje Y izquierdo
ax1.plot(data_subset.index, data_subset['MAP'], color='blue', label='MAP')
ax1.set_xlabel('Tiempo (s)')
ax1.set_ylabel('MAP (MPa)', color='blue')
ax1.tick_params('y', colors='blue')

# Crear un segundo eje Y para throttle_position e injected_fuel_mass
ax2 = ax1.twinx()

# Escalar los valores de injected_fuel_mass para ajustar la escala
scaling_factor = 10000  # Ajusta este valor según tu preferencia
ax2.plot(data_subset.index, data_subset['posicion_acelerador'], color='green', label='Posicion del pedal de aceleración')
ax2.plot(data_subset.index, data_subset['masa_combustible_inyectado'] * scaling_factor, color='red', label='Masa de combustible inyectada (escalado)')
ax2.set_ylabel('Posicion del pedal de aceleración (%)\n Masa de combustible inyectado (g)', color='black')
ax2.tick_params('y', colors='black')

# Añadir leyenda
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

# Mostrar la gráfica
plt.show()

# %%
# Filtrar los datos para incluir solo los primeros 120 segundos
data_subset = data[(data.index > 0) & (data.index < 6)]

# Crear la figura y los ejes
fig, ax1 = plt.subplots()

# Graficar MAP en el eje Y izquierdo
ax1.plot(data_subset.index, data_subset['MAP'], color='blue', label='MAP')
ax1.set_xlabel('Tiempo (s)')
ax1.set_ylabel('MAP (MPa)', color='blue')
ax1.tick_params('y', colors='blue')

# Crear un segundo eje Y para throttle_position e injected_fuel_mass
ax2 = ax1.twinx()

# Escalar los valores de injected_fuel_mass para ajustar la escala
ax2.plot(data_subset.index, data_subset['posicion_acelerador'], color='green', label='Posicion del pedal de aceleración')
ax2.set_ylabel('Posicion del pedal de aceleración (%)', color='black')
ax2.tick_params('y', colors='black')

# Añadir leyenda
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

# Mostrar la gráfica
plt.show()

# %%
# Filtrar los datos para incluir solo los primeros 120 segundos
data_subset = data[(data.index > 780) & (data.index < 790)]

# Crear la figura y los ejes
fig, ax1 = plt.subplots()

# Graficar MAP en el eje Y izquierdo
ax1.plot(data_subset.index, data_subset['MAP'], color='blue', label='MAP')
ax1.set_xlabel('Tiempo (s)')
ax1.set_ylabel('MAP (MPa)', color='blue')
ax1.tick_params('y', colors='blue')

# Crear un segundo eje Y para throttle_position e injected_fuel_mass
ax2 = ax1.twinx()

# Escalar los valores de injected_fuel_mass para ajustar la escala
ax2.plot(data_subset.index, data_subset['posicion_acelerador'], color='green', label='Posicion del pedal de aceleración')
ax2.set_ylabel('Posicion del pedal de aceleración (%)', color='black')
ax2.tick_params('y', colors='black')

# Añadir leyenda
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

# Mostrar la gráfica
plt.show()

# %%
# Filtrar los datos para incluir solo los primeros 120 segundos
data_subset = data[(data.index > 1400) & (data.index < 1500)]

# Crear la figura y los ejes
fig, ax1 = plt.subplots()

# Graficar MAP en el eje Y izquierdo
ax1.plot(data_subset.index, data_subset['MAP'], color='blue', label='MAP')
ax1.set_xlabel('Tiempo (s)')
ax1.set_ylabel('MAP (MPa)', color='blue')
ax1.tick_params('y', colors='blue')

# Crear un segundo eje Y para throttle_position e injected_fuel_mass
ax2 = ax1.twinx()

# Escalar los valores de injected_fuel_mass para ajustar la escala
ax2.plot(data_subset.index, data_subset['velocidad_motor'], color='green', label='Velocidad del Motor')
ax2.set_ylabel('Velocidad del Motor (RPMx10)', color='black')
ax2.tick_params('y', colors='black')


# Añadir leyenda
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

# Mostrar la gráfica
plt.show()
